# %% [markdown]
# ## Importing and plotting data

# %%
# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Import pandas
import pandas as pd
# Import numpy
import numpy as np
# %matplotlib inline

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:850px;  /* desired max-height */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:850px;  /* desired max-height */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
path = "/Users/ingmar/Documents/Development/Kaggle Instacart/input-data/"

# %%
prior = pd.read_csv(path + "order_products__prior.csv")

# %%
# Print the head of the DataFrame
print(prior.head())
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Plot 'product_id' variable in a histogram
pd.DataFrame.hist(data=prior[['product_id']], xlabelsize=15, ylabelsize=15, bins=1500, color='r', figsize=(10, 6))
plt.xlabel('Product ID', fontsize=20)
plt.ylabel('count', fontsize=20)
plt.show()

# %%
# Plot 'Add to Cart' variable in a histogram
pd.DataFrame.hist(data=prior[['add_to_cart_order']], xlabelsize=15, ylabelsize=15, bins=500, color='r', figsize=(10, 6))
plt.xlabel('Add to cart order', fontsize=20)
plt.ylabel('count', fontsize=20)
plt.show()

# %%
plt.scatter(x=prior[['add_to_cart_order']], y=prior[['add_to_cart_order']].index)

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
fig, ax = plt.subplots()

ax.plot(x, y, color="blue", alpha=1.5, linewidth=5, linestyle='-.', marker='o', markersize=20, markerfacecolor='yellow', markeredgecolor='green', markeredgewidth=5)
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
# Plot 'reordered' variable in a histogram
pd.DataFrame.hist(data=prior[['reordered']], xlabelsize=15, ylabelsize=15, bins=3, color='r', figsize=(10, 6))
plt.xlabel('Reordered', fontsize=20)
plt.ylabel('count', fontsize=20)
plt.show()

# %%
orders = pd.read_csv(path + "orders.csv")

# %%
print(orders.head())
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Plot 'ohod' variable in a histogram
pd.DataFrame.hist(data=orders[['order_hour_of_day']], xlabelsize=15, ylabelsize=15, bins=24, color='r', figsize=(10, 6))
plt.xlabel('Hour of the day', fontsize=20)
plt.ylabel('count', fontsize=20)
plt.show()

# %%
# Plot 'odow' variable in a histogram
pd.DataFrame.hist(data=orders[['order_dow']], xlabelsize=15, ylabelsize=15, bins=7, color='r', figsize=(12, 7))
plt.xlabel('Day of the week', fontsize=20)
plt.ylabel('count', fontsize=20)
plt.show()

# %%
# Plot 'dspo' variable in a histogram
pd.DataFrame.hist(data=orders[['days_since_prior_order']], xlabelsize=15, ylabelsize=15, bins=30, color='r', figsize=(10, 6))
plt.xlabel('Days since prior order', fontsize=20)
plt.ylabel('count', fontsize=20)
plt.show()
